# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from pandas import read_excel

# %%
df_prod = pd.read_csv("reporte_mayo_octubre - reporte-productos (2) (3).csv")
df_prod
# Out:
# /tmp/ipykernel_2061/4182693211.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_prod = pd.read_csv("reporte_mayo_octubre - reporte-productos (2) (3).csv")
#                            Fecha               Negocio  Facturador  Vendedor  \
# 0      2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios    Astrid
# 1      2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios    Astrid
# 2      2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios    Astrid
# 3      2022-05-04 09:05:58 p. m.  Primal Alimentos SAS  Pablo Rios    Astrid
# 4      2022-05-04 09:05:58 p. m.  Primal Alimentos SAS  Pablo Rios    Astrid
# ...                          ...                   ...         ...       ...
# 38531  2022-10-17 11:23:05 p. m.  Primal Alimentos SAS      Astrid  Kasandra
# 38532  2022-10-17 11:23:05 p. m.  Primal Alimentos SAS      Astrid  Kasandra
# ...

# %%
df_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38536 entries, 0 to 38535
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Fecha                   38536 non-null  object
#  1   Negocio                 38536 non-null  object
#  2   Facturador              38536 non-null  object
#  3   Vendedor                38536 non-null  object
#  4   Proveedor de Domicilio  5 non-null      object
#  5   Cliente                 38536 non-null  object
#  6   Mesa                    38536 non-null  object
#  7   No. Factura             38536 non-null  object
#  8   Total Factura           38536 non-null  object
#  9   Categoría               38536 non-null  object
#  10  Código                  1 non-null      float64
#  11  Producto                38536 non-null  object
#  12  Cantidad                38527 non-null  float64
#  13  Precio de venta         38536 non-null  object
# ...

# %%
df_prod.columns
# Out:
# Index(['Fecha', 'Negocio', 'Facturador', 'Vendedor', 'Proveedor de Domicilio',
#        'Cliente', 'Mesa', 'No. Factura', 'Total Factura', 'Categoría',
#        'Código', 'Producto', 'Cantidad', 'Precio de venta', 'Valor Promoción',
#        'Valor Ventas', 'Valor Descuentos', 'Valor Neto', 'Impuesto',
#        'Base Imp.', 'Total Imp.', 'Total'],
#       dtype='object')

# %%
df_prod['Precio de venta'] = [x[:-3] for x in df_prod['Precio de venta']]

# %%
df_prod['Total']
# Out:
# 0         6.200,00
# 1        32.000,00
# 2        34.000,00
# 3         5.000,00
# 4        16.000,00
#            ...
# 38531     1.000,00
# 38532     7.500,00
# 38533     7.800,00
# 38534    10.000,00
# 38535     3.000,00
# Name: Total, Length: 38536, dtype: object

# %%
# Remove $ sign
#df_prod['Total'] = [x[1:] for x in df_prod['Total']]

# %%
df_prod['Total'] = [x[:-3] for x in df_prod['Total']]
df_prod['Valor Descuentos'] = [x[:-3] for x in df_prod['Valor Descuentos']]
df_prod['Total Imp.'] = [x[:-3] for x in df_prod['Total Imp.']]

# %%
# df_prod['Precio de venta'] = df_prod['Precio de venta'].str.replace(',', '.')
df_prod.head()
# Out:
#                        Fecha               Negocio  Facturador Vendedor  \
# 0  2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
# 1  2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
# 2  2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
# 3  2022-05-04 09:05:58 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
# 4  2022-05-04 09:05:58 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
#
#   Proveedor de Domicilio  Cliente Mesa No. Factura Total Factura  \
# 0                    NaN  General    1   A10024210     72.200,00
# 1                    NaN  General    1   A10024210     72.200,00
# 2                    NaN  General    1   A10024210     72.200,00
# 3                    NaN  General    3   A10024211     69.500,00
# 4                    NaN  General    3   A10024211     69.500,00
#
#          Categoría  ...  Cantidad Precio de venta  Valor Promoción  \
# 0          Bebidas  ...       1.0           6.200                0
# ...

# %%
df_prod['Precio de venta'] = df_prod['Precio de venta'].str.replace('.', '')
# Out:
# /tmp/ipykernel_2061/3993051426.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_prod['Precio de venta'] = df_prod['Precio de venta'].str.replace('.', '')

# %%
df_prod['Total'] = df_prod['Total'].str.replace('.', '')
df_prod['Valor Descuentos'] = df_prod['Valor Descuentos'].str.replace('.', '')
df_prod['Total Imp.'] = df_prod['Total Imp.'].str.replace('.', '')
# Out:
# /tmp/ipykernel_2061/18796460.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_prod['Total'] = df_prod['Total'].str.replace('.', '')
# /tmp/ipykernel_2061/18796460.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_prod['Valor Descuentos'] = df_prod['Valor Descuentos'].str.replace('.', '')
# /tmp/ipykernel_2061/18796460.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_prod['Total Imp.'] = df_prod['Total Imp.'].str.replace('.', '')

# %%
df_prod['Total'] = pd.to_numeric(df_prod['Total'])
df_prod['Total Imp.'] = pd.to_numeric(df_prod['Total Imp.'])

# %%
df_prod['Precio de venta'] = pd.to_numeric(df_prod['Precio de venta'])

# %%
df_prod.iloc[16889]
# Out:
# Fecha                     2022-07-14 04:04:01 a. m.
# Negocio                        Primal Alimentos SAS
# Facturador                                   Astrid
# Vendedor                                   Kasandra
# Proveedor de Domicilio                          NaN
# Cliente                                     General
# Mesa                                              1
# No. Factura                               A10028170
# Total Factura                             73.500,00
# Categoría                                   Bebidas
# Código                                          NaN
# Producto                             NV LIMO SANDIA
# Cantidad                                        1.0
# Precio de venta                              7500.0
# Valor Promoción                                   0
# Valor Ventas                               6.944,44
# Valor Descuentos
# Valor Neto                                 6.944,44
# Impuesto                             I CONSUMO (8%)
# ...

# %%
df_prod.iloc[47348]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2061/4100861209.py in <module>
# ----> 1 df_prod.iloc[47348]
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1072
#    1073             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1074             return self._getitem_axis(maybe_callable, axis=axis)
#    1075
#    1076     def _is_scalar_access(self, key: tuple):
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1624
#    1625             # validate the location
# -> 1626             self._validate_integer(key, axis)
#    1627
#    1628             return self.obj._ixs(key, axis=axis)
#
# ...

# %%
df_prod['Total'].index[16889]
# Out:
# 16889

# %%
df_prod.dtypes
# Out:
# Fecha                      object
# Negocio                    object
# Facturador                 object
# Vendedor                   object
# Proveedor de Domicilio     object
# Cliente                    object
# Mesa                       object
# No. Factura                object
# Total Factura              object
# Categoría                  object
# Código                    float64
# Producto                   object
# Cantidad                  float64
# Precio de venta           float64
# Valor Promoción             int64
# Valor Ventas               object
# Valor Descuentos           object
# Valor Neto                 object
# Impuesto                   object
# Base Imp.                  object
# Total Imp.                float64
# Total                     float64
# dtype: object

# %%
df_prod.head()
# Out:
#                        Fecha               Negocio  Facturador Vendedor  \
# 0  2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
# 1  2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
# 2  2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
# 3  2022-05-04 09:05:58 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
# 4  2022-05-04 09:05:58 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
#
#   Proveedor de Domicilio  Cliente Mesa No. Factura Total Factura  \
# 0                    NaN  General    1   A10024210     72.200,00
# 1                    NaN  General    1   A10024210     72.200,00
# 2                    NaN  General    1   A10024210     72.200,00
# 3                    NaN  General    3   A10024211     69.500,00
# 4                    NaN  General    3   A10024211     69.500,00
#
#          Categoría  ...  Cantidad Precio de venta  Valor Promoción  \
# 0          Bebidas  ...       1.0          6200.0                0
# ...

# %%
df_prod['Hora']=df_prod['Fecha'].str.extract(r'(\d{2}:\d{2}:\d{2})')

# %%
df_prod['Dia']=df_prod['Fecha'].str.extract(r'(\d{4}-\d{2}-\d{2})')

# %%
df_prod
# Out:
#                            Fecha               Negocio  Facturador  Vendedor  \
# 0      2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios    Astrid
# 1      2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios    Astrid
# 2      2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios    Astrid
# 3      2022-05-04 09:05:58 p. m.  Primal Alimentos SAS  Pablo Rios    Astrid
# 4      2022-05-04 09:05:58 p. m.  Primal Alimentos SAS  Pablo Rios    Astrid
# ...                          ...                   ...         ...       ...
# 38531  2022-10-17 11:23:05 p. m.  Primal Alimentos SAS      Astrid  Kasandra
# 38532  2022-10-17 11:23:05 p. m.  Primal Alimentos SAS      Astrid  Kasandra
# 38533  2022-10-17 11:23:05 p. m.  Primal Alimentos SAS      Astrid  Kasandra
# 38534  2022-10-17 11:23:29 p. m.  Primal Alimentos SAS      Astrid   Viviana
# 38535  2022-10-17 11:23:29 p. m.  Primal Alimentos SAS      Astrid   Viviana
#
# ...

# %%
df_prod['Hora'] = pd.to_datetime(df_prod['Hora'],format= '%H:%M:%S' ).dt.time

# %%
df_prod.head()
# Out:
#                        Fecha               Negocio  Facturador Vendedor  \
# 0  2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
# 1  2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
# 2  2022-05-04 09:05:41 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
# 3  2022-05-04 09:05:58 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
# 4  2022-05-04 09:05:58 p. m.  Primal Alimentos SAS  Pablo Rios   Astrid
#
#   Proveedor de Domicilio  Cliente Mesa No. Factura Total Factura  \
# 0                    NaN  General    1   A10024210     72.200,00
# 1                    NaN  General    1   A10024210     72.200,00
# 2                    NaN  General    1   A10024210     72.200,00
# 3                    NaN  General    3   A10024211     69.500,00
# 4                    NaN  General    3   A10024211     69.500,00
#
#          Categoría  ...  Precio de venta Valor Promoción  Valor Ventas  \
# ...

# %%
df_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38536 entries, 0 to 38535
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Fecha                   38536 non-null  object
#  1   Negocio                 38536 non-null  object
#  2   Facturador              38536 non-null  object
#  3   Vendedor                38536 non-null  object
#  4   Proveedor de Domicilio  5 non-null      object
#  5   Cliente                 38536 non-null  object
#  6   Mesa                    38536 non-null  object
#  7   No. Factura             38536 non-null  object
#  8   Total Factura           38536 non-null  object
#  9   Categoría               38536 non-null  object
#  10  Código                  1 non-null      float64
#  11  Producto                38536 non-null  object
#  12  Cantidad                38527 non-null  float64
#  13  Precio de venta         32151 non-null  float64
# ...

# %%
# df_horas = df_prod[['Fecha','Producto','']]

# %%
df_prod.to_csv('dias_horas_df.csv', index = False, encoding='utf-8')

# %%
from datetime import date

d0 = date(2022, 5, 5)
d1 = date(2022, 10, 18)
delta = d1 - d0
print(delta.days)
# Out:
# 166

# %%
# df['Fecha'] = pd.to_datetime(df['date_col'], format='%Y-%m-%d %H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2061/3749245491.py in <module>
# ----> 1 df['Fecha'] = pd.to_datetime(df['date_col'], format='%Y-%m-%d %H:%M:%S')
#
# NameError: name 'df' is not defined

# %%
# df['Fecha'] = int(df['Fecha'])

# %%
# df['Fecha'].dtype

# %%
# df_prod['fecha_columna'] = pd.to_datetime((df_prod['Fecha'])).dt.date

# %%
# df_prod['fecha_columna'].dtype()

# %%
# df_prod['hora'] = df_prod['fecha_columna'].dt.hour

# %%
df_prod.info()

# %%
df_prod.to_csv('productos_df.csv', index = False, encoding='utf-8')

# %%
# from datetime import date

# d0 = date(2022, 5, 5)
# d1 = date(2022, 10, 18)
# delta = d1 - d0
# print(delta.days)
